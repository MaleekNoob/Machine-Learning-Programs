# %%
import tensorflow as tf
data = tf.keras.datasets.fashion_mnist

(training_images, training_labels), (test_images, test_labels) = data.load_data()

training_images = training_images / 255.0
test_images = test_images / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.fit(training_images, training_labels, epochs=5)

model.evaluate(test_images, test_labels)

classifications = model.predict(test_images)

print(classifications[0])

print(test_labels[0])

# Exercise 1

# %%
# FreeCodeCamp
import tensorflow as tf
import numpy as np
mnist = tf.keras.datasets.mnist

print("Loading data...")

# %%
# Building neural network model from scratch
def w_sum(input, weights):
    assert (len(input) == len(weights))
    result = 0
    for i in range(len(input)):
        result += input[i] * weights[i]

    return result

def neural_network(input, weights):
    pred = w_sum(input, weights)
    return pred

weights = [0.1, 0.2, 0]

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

input = [toes[0], wlrec[0], nfans[0]]

main_pred = neural_network(input, weights)

print("According to toes: " + str(toes[0]) + ", wlrec: " + str(wlrec[0]) + ", nfans: " + str(nfans[0]))
print("Win Prediction: " + str(main_pred))

# %%
# Implementing a neural network with numpy
import numpy as np

def neural_network(input, weights):
    return input.dot(weights)

weights = np.array([0.1, 0.2, 0])

toes = np.array([8.5, 9.5, 9.9, 9.0])
wlrec = np.array([0.65, 0.8, 0.8, 0.9])
nfans = np.array([1.2, 1.3, 0.5, 1.0])

input = np.array([toes[0], wlrec[0], nfans[0]])

main_pred = neural_network(input, weights)

print("According to toes: " + str(toes[0]) + ", wlrec: " + str(wlrec[0]) + ", nfans: " + str(nfans[0]))
print("Win Prediction: " + str(main_pred))

# %%
# Implementing a neural network with multiple inputs and outputs

def w_sum(vect, matrix):
    assert (len(vect) == len(matrix))
    result = 0
    for i in range(len(vect)):
        result += vect[i] * matrix[i]
    
    return result

def neural_network(input, weights):
    assert (len(input) == len(weights))
    output = [0] * len(weights)
    for i in range(len(input)):
        output[i] = w_sum(input, weights[i])
        
    return output

weights = [[0.1, 0.1, -0.3], # hurt?
            [0.1, 0.2, 0.0], # win?
            [0.0, 1.3, 0.1]] # sad?

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

input = [toes[0], wlrec[0], nfans[0]]

main_pred = neural_network(input, weights)
print(main_pred)

# %%
def w_sum(vect, matrix):
    assert len(vect) == len(matrix)
    result = 0
    for i in range(len(vect)):
        result += vect[i] * matrix[i]
    return result

def vect_mat_mul(vect, matrix):
    assert len(vect) == len(matrix)
    output = [0] * len(vect)
    for i in range(len(vect)):
        output[i] = w_sum(vect, matrix[i])
    return output

def neural_network(input, weights):
    hid = vect_mat_mul(input, weights[0])
    pred = vect_mat_mul(hid, weights[1])
    return pred

ih_wgt = [[0.1, 0.2, -0.1],  # hid[0]
          [-0.1, 0.1, 0.9],  # hid[1]
          [0.1, 0.4, 0.1]]  # hid[2]

hp_wgt = [[0.3, 1.1, -0.3],  # hurt?
          [0.1, 0.2, 0.0],  # win?
          [0.0, 1.3, 0.1]]  # sad?

weights = [ih_wgt, hp_wgt]

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

input = [toes[0], wlrec[0], nfans[0]]

pred = neural_network(input, weights)
print(pred)

# %%
# Implementing a neural network with multiple inputs and outputs with numpy
import numpy as np

def neural_network(input, weights):
    hid = input.dot(weights[0])
    pred = hid.dot(weights[1])
    return pred

ih_wgt = np.array([[0.1, 0.2, -0.1],  # hid[0]
            [-0.1, 0.1, 0.9],  # hid[1]
            [0.1, 0.4, 0.1]]).T  # hid[2]

hp_wgt = np.array([[0.3, 1.1, -0.3],  # hurt?
            [0.1, 0.2, 0.0],  # win?
            [0.0, 1.3, 0.1]]).T  # sad?

weights = [ih_wgt, hp_wgt]

toes = np.array([8.5, 9.5, 9.9, 9.0])
wlrec = np.array([0.65, 0.8, 0.8, 0.9])
nfans = np.array([1.2, 1.3, 0.5, 1.0])

input = np.array([toes[0], wlrec[0], nfans[0]])

pred = neural_network(input, weights)
print(pred)

# %%
# Evaluationg neural network error with mean squared error

weight = 0.1
lr = 0.01

def neural_network(input, weight):
    print("input: " + str(input) + " X weight: " + str(weight) + " = " + str(input * weight))
    return input * weight

number_of_toes = [8.5]
win_or_lose_binary = [1] # (won!!!)
input = number_of_toes[0]
true = win_or_lose_binary[0]
pred = neural_network(input,weight)
error = (pred - true) ** 2
print(error)
lr = 0.1
p_up = neural_network(input,weight+lr)
e_up = (p_up - true) ** 2
print(e_up)
lr = 0.01
p_dn = neural_network(input,weight-lr)
e_dn = (p_dn - true) ** 2
print(e_dn)

if (error > e_dn or error > e_up):
    if(e_dn < e_up):
        weight -= lr
    if(e_up < e_up):
        weight += lr

# %%
# Simplest form of Learning

weight = 0.5
input = 0.25
goal_prediction = 0.8
step_amount = 0.01
for iteration in range(1101):
    prediction = input * weight
    error = (prediction - goal_prediction) ** 2
    print("Error:" + str(error) + " Prediction:" + str(prediction))

    up_prediction = input * (weight + step_amount)
    up_error = (goal_prediction - up_prediction) ** 2
    down_prediction = input * (weight - step_amount)
    down_error = (goal_prediction - down_prediction) ** 2
    if(down_error < up_error):
        weight = weight - step_amount

    if(down_error > up_error):
        weight = weight + step_amount

print("Final weight: " + str(weight))

# %%
# gradient descent

weight = 0.5
goal_pred = 0.8
input = -0.5
for iteration in range(20):
 pred = input * weight
 error = (pred - goal_pred) ** 2
 direction_and_amount = (pred - goal_pred) * input
 weight = weight - direction_and_amount
 print("Error:" + str(error) + " Prediction:" + str(pred))

# %%
# gradient descent by reducing error

input = 0.99
weight = 1
output = 0.8
alpha = 1 # Tweaking alpha can help reduce divergence

for i in range(5):
    pred = input * weight # Prediction is basically the product of input times weight
    error = (pred - output) ** 2 # finding mean square error (mean is error itself as we're dealing with only one observation)
    derivative = input * (pred - output) # shows estimated direction and magnitude of error
    weight -= alpha * derivative # alpha used to minimize divergence
    print("Accuracy: " + str(1 - error) + " Prediction: " + str(pred) + " Error: " + str(error))

# %%
# my logic using derivatives

input = 8
output = 0.8
weight = output/input

pred = weight * input
error = (pred - output) ** 2
print("Accuracy: " + str(1 - error) + " Prediction: " + str(pred) + " Error: " + str(error))
# Out:
# Accuracy: 1.0 Prediction: 0.8 Error: 0.0
